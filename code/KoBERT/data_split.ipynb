# %%
import pandas as pd

# %%
df = pd.read_csv("../data/ad_article.csv")

# %%
df = df.iloc[:,[1,2,3,4]]
df['label'] = 1
df.columns = ['title', 'body', 'writer', 'media', 'label']

# %%
df_train = df.iloc[:900, :]
df_test = df.iloc[900:, :]

# %%
df_train
# Out:
#                                                  title  \
# 0       [탐방-청담씨티칼리지 요양병원] 여성 암환자 명품 쉼터… 명실상부 회복공간 자리매김
# 1    [수술 잘하는 병원-이대목동병원 심장이식팀] 환자 맞춤형 최적 치료 제공… 수술후 ...
# 2                             알록달록 이국 풍경… ‘부네치아’를 아시나요
# 3                         용인 ‘수지 스카이뷰 푸르지오’ 4일 본보기집 개관
# 4                                 교통-쇼핑-의료 ‘3박자’ 다 갖췄네
# ..                                                 ...
# 895                       GTX 서울역까지 20분… 강남·여의도 버스망 편리
# 896                        포항 주거 중심지… 대지의 35%를 조경 면적으로
# 897           세운지구 13년 만에 아파트 첫 공급…6월 말 ‘힐스테이트 세운’ 선보여
# 898                        [열정! e경영인]신발 관리용품 전문몰 '슈닥터'
# 899              [추천 이 상품]청호 직수 정수기 '콤팩트'…1인가구 주방에 딱이네
#
#                                                   body  \
# 0    청담씨티칼리지 요양병원 내·외부 모습.\n\n\n요즘 요양병원에 대한 사회적 인식이...
# 1    국내 심장 분야 명의로 꼽히는 이대목동병원 심장이식팀 서동만(왼쪽) 흉부외과 교수와...
# 2    일몰·일출… 색다른 부산 여행\n부산 사하구 장림포구가 알록달록한 건물과 일몰로 황...
# 3    대우건설은 경기 용인시 수지구 신봉동 ‘수지 스카이뷰 푸르지오’를 분양한다. 지하 ...
# ...
